# %%
import numpy as np
import matplotlib.pyplot as plt

from hcipy import *
from hcipy.aperture import make_subaru_aperture

# %%
pupil_grid = make_pupil_grid(256)

telescope_pupil_generator = make_subaru_aperture()

# %%
telescope_pupil = telescope_pupil_generator(pupil_grid)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 telescope_pupil = telescope_pupil_generator(pupil_grid)
#
# TypeError: 'NoneType' object is not callable

# %%
im = imshow_field(telescope_pupil, cmap='gray')
plt.colorbar()
plt.xlabel('x / D')
plt.ylabel('y / D')
plt.show()

# %%
pupil_grid = make_pupil_grid(256)

telescope_pupil_generator = make_subaru_aperture()

telescope_pupil = telescope_pupil_generator(pupil_grid)

im = imshow_field(telescope_pupil, cmap='gray')
plt.colorbar()
plt.xlabel('x / D')
plt.ylabel('y / D')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[47], line 5
#       1 pupil_grid = make_pupil_grid(256)
#       3 telescope_pupil_generator = make_subaru_aperture()
# ----> 5 telescope_pupil = telescope_pupil_generator(pupil_grid)
#       7 im = imshow_field(telescope_pupil, cmap='gray')
#       8 plt.colorbar()
#
# TypeError: 'NoneType' object is not callable

# %%
import hcipy
import hcipy.aperture as aperture

print("HCIPy version:", hcipy.__version__)
print("Subaru function:", aperture.make_subaru_aperture)

subaru = aperture.make_subaru_aperture()
print("Returned object:", subaru)
print("Is callable?", callable(subaru))
# Out:
# HCIPy version: 0.6.0
# Subaru function: <function make_subaru_aperture at 0x10fb75b20>
# Returned object: None
# Is callable? False
